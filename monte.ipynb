# %%
import numpy as np
from numpy import random

# %%
a=0
b=1.5 * np.pi
N=1000000

# %%
ymax=1
ymin=-1

# %%
random.rand()
# Out:
# 0.803737842246594

# %%
def f(x):
    return np.cos(x)

# %%
inside=0
for i in range(N):
    x=random.rand() *(b-a)
    y=random.rand() *(ymax-ymin) + ymin
    if(f(x)> 0):
        if(f(x) >= y and y >0 ):
            inside+=1
    else: 
        if(f(x) <= y and y<0):
            inside-=1
print("intergration", red/N  * (2 * 3/2 * np.pi))
# Out:
# intergration -0.9952848269911287

# %%
# Out:
# -1.0
