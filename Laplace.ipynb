# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x0=0
xf=1
y0=0
yf=1

N=100
M=100
delta_y=(yf-y0)/M+2
delta_x=delta_y
V=np.zeros((N+2,M+2))
for i in range(M+2):
    V[i][0]=np.sin(2*np.pi*delta_y*i)
for itr in range(100):
    for i in range(1,N+1):
        for j in range(1,M+1):
            V[i][j]=(V[i-1][j] +V[i+1][j]+V[i][j-1] +V[i][j+1])/4
            
# plot it in color plot.
plt.imshow(V, extent=[x0, xf, y0, yf], origin='lower', cmap='jet')
plt.colorbar()
plt.show()

# %%
F=np.zeros((N,M))
for i in range(N):
    for j in range(M):
        k=int(j/N) +i

# %%
M=3
N=3
Dy=np.zeros((N*M,N*M))
for n in range(1,N+1):
    for m in range(1,M+1):
        #create a 1D label
        i=(m-1)*N+n
        Dy[i-1][i-1]=-2
        if(m>1):
            j=i-N
            Dy[i-1,j-1]=1
        if(m<M):
            j=i+N
            Dy[i-1,j-1]=1
Dy = Dy / delta_y**2
# Out:
# array([[-2.,  0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.],
#        [ 0., -2.,  0.,  0.,  1.,  0.,  0.,  0.,  0.],
#        [ 0.,  0., -2.,  0.,  0.,  1.,  0.,  0.,  0.],
#        [ 1.,  0.,  0., -2.,  0.,  0.,  1.,  0.,  0.],
#        [ 0.,  1.,  0.,  0., -2.,  0.,  0.,  1.,  0.],
#        [ 0.,  0.,  1.,  0.,  0., -2.,  0.,  0.,  1.],
#        [ 0.,  0.,  0.,  1.,  0.,  0., -2.,  0.,  0.],
#        [ 0.,  0.,  0.,  0.,  1.,  0.,  0., -2.,  0.],
#        [ 0.,  0.,  0.,  0.,  0.,  1.,  0.,  0., -2.]])
